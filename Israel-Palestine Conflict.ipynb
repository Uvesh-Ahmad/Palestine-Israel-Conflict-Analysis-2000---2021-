# %% [markdown]
# # Human Cost of Israel-Palestine Conflict (2000 - 2021) Analysis

# %%
from IPython.display import Image
Image(filename='C:/Users/mrala/OneDrive/Desktop/Data Analyst project/Israel.jpeg')

# %%
import numpy as np
import pandas as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\mrala\OneDrive\Desktop\Python Data\Data Analyst Project (Linkedin)\Israel-Palestine Conflict.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/mrala/OneDrive/Desktop/Python%20Data/Data%20Analyst%20Project%20%28Linkedin%29/Israel-Palestine%20Conflict.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> import numpy as np
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mrala/OneDrive/Desktop/Python%20Data/Data%20Analyst%20Project%20%28Linkedin%29/Israel-Palestine%20Conflict.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> import pandas as np
#       <a href='vscode-notebook-cell:/c%3A/Users/mrala/OneDrive/Desktop/Python%20Data/Data%20Analyst%20Project%20%28Linkedin%29/Israel-Palestine%20Conflict.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/c%3A/Users/mrala/OneDrive/Desktop/Python%20Data/Data%20Analyst%20Project%20%28Linkedin%29/Israel-Palestine%20Conflict.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> import seaborn as sns
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install seaborn
